# %%
import pandas as pd
import altair as alt

# %%
batting_df = pd.read_csv('../combined_data/batting_combined_fill_na.csv')
pitching_df = pd.read_csv('../combined_data/pitching_combined.csv')
standing_df = pd.read_csv('../combined_data/detailed_standings_combined.csv')

# %%
batting_df['missing_value_count'] = batting_df.isnull().sum(axis=1)
pitching_df['missing_value_count'] = pitching_df.isnull().sum(axis=1)
standing_df['missing_value_count'] = standing_df.isnull().sum(axis=1)

# %%
batting_numeric_columns = batting_df.select_dtypes(include='number').columns
batting_grouped_by_year_df = batting_df.groupby('Year', as_index=False)[batting_numeric_columns].mean()

pitching_numeric_columns = pitching_df.select_dtypes(include='number').columns
pitching_grouped_by_year_df = pitching_df.groupby('Year', as_index=False)[pitching_numeric_columns].mean()

standing_numeric_columns = standing_df.select_dtypes(include='number').columns
standing_grouped_by_year_df = standing_df.groupby('Year', as_index=False)[standing_numeric_columns].mean()

# %% [markdown]
# # Yosef- I used altair to create a plot visualizing missing values in the batting data  for each league.

# %%
batting_grouped_by_league_year_df = batting_df.groupby(['League', 'Year'])['missing_value_count'].mean().reset_index()

selection = alt.selection_multi(fields=['League'], bind='legend')

chart = alt.Chart(batting_grouped_by_league_year_df).mark_line(point=True).encode(
    x='Year:O',
    y='missing_value_count:Q',
    color='League:N',
    tooltip=['League', 'Year', 'missing_value_count'],
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
).properties(
    title='Average BATTING Missing Values Over Time by League - Altair',
    width=800,
    height=400
).add_selection(
    selection
).interactive()

chart
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.Chart(...)

# %% [markdown]
# ### Ethan - Below is the same visualization for Pitching and DETAILED standings

# %%
pitching_grouped_by_league_year_df = pitching_df.groupby(['League', 'Year'])['missing_value_count'].mean().reset_index()

selection = alt.selection_multi(fields=['League'], bind='legend')

chart = alt.Chart(pitching_grouped_by_league_year_df).mark_line(point=True).encode(
    x='Year:O',
    y='missing_value_count:Q',
    color='League:N',
    tooltip=['League', 'Year', 'missing_value_count'],
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
).properties(
    title='Average PITCHING Missing Values Over Time by League - Altair',
    width=800,
    height=400
).add_selection(
    selection
).interactive()

chart
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.Chart(...)

# %%
standing_grouped_by_league_year_df = standing_df.groupby(['League', 'Year'])['missing_value_count'].mean().reset_index()

selection = alt.selection_multi(fields=['League'], bind='legend')

chart = alt.Chart(standing_grouped_by_league_year_df).mark_line(point=True).encode(
    x='Year:O',
    y='missing_value_count:Q',
    color='League:N',
    tooltip=['League', 'Year', 'missing_value_count'],
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
).properties(
    title='Average Standing Missing Values Over Time by League - Altair',
    width=800,
    height=400
).add_selection(
    selection
).interactive()

chart
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.Chart(...)

# %% [markdown]
# #### Yosef - Wanted to plot average batting age, runs, and number of home runs over time but this data wasn't accurate to our dataset at first.

# %%
# # Plot the average batting age over time
# plt.figure(figsize=(10, 6))
# plt.plot(grouped_by_year_df['Year'], grouped_by_year_df['BatAge'], m  arker='o')
# plt.title('Average Batting Age Over Time')
# plt.xlabel('Year')
# plt.ylabel('Average Batting Age')
# plt.grid(True)
# plt.show()

# # Plot the average runs per game over time
# plt.figure(figsize=(10, 6))
# plt.plot(grouped_by_year_df['Year'], grouped_by_year_df['R/G'], marker='o')
# plt.title('Average Runs Per Game Over Time')
# plt.xlabel('Year')
# plt.ylabel('Average Runs Per Game')
# plt.grid(True)
# plt.show()

# # Plot the average number of home runs over time
# plt.figure(figsize=(10, 6))
# plt.plot(grouped_by_year_df['Year'], grouped_by_year_df['HR'], marker='o')
# plt.title('Average Number of Home Runs Over Time')
# plt.xlabel('Year')
# plt.ylabel('Average Number of Home Runs')
# plt.grid(True)
# plt.show()

# %%
# import altair as alt

# # Create an Altair chart for the average batting age over time
# bat_age_chart = alt.Chart(grouped_by_year_df).mark_line(point=True).encode(
#     x='Year:O',
#     y='BatAge:Q',
#     tooltip=['Year', 'BatAge']
# ).properties(
#     title='Average Batting Age Over Time - Altair',
#     width=800,
#     height=400
# ).interactive()

# # Create an Altair chart for the average runs per game over time
# runs_per_game_chart = alt.Chart(grouped_by_year_df).mark_line(point=True).encode(
#     x='Year:O',
#     y='R/G:Q',
#     tooltip=['Year', 'R/G']
# ).properties(
#     title='Average Runs Per Game Over Time - Altair',
#     width=800,
#     height=400
# ).interactive()

# # Create an Altair chart for the average number of home runs over time
# home_runs_chart = alt.Chart(grouped_by_year_df).mark_line(point=True).encode(
#     x='Year:O',
#     y='HR:Q',
#     tooltip=['Year', 'HR']
# ).properties(
#     title='Average Number of Home Runs Over Time - Altair',
#     width=800,
#     height=400
# ).interactive()

# # Display the charts
# bat_age_chart & runs_per_game_chart & home_runs_chart

# %% [markdown]
# ### Yosef - Players League Quanity of Publications Over Time
#     - one through matplotlib and one through altair

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
pl_data_df = pd.read_csv('../chroniclingamerica_csv/pl_data.csv')

# Ensure the 'Date' column is in datetime format
pl_data_df['Date'] = pd.to_datetime(pl_data_df['date'])

# Group by year and count the number of publications
pl_data_df['Year'] = pl_data_df['Date'].dt.year
publications_per_year = pl_data_df.groupby('Year').size().reset_index(name='Quantity')

# Plot the time series
plt.figure(figsize=(10, 6))
plt.plot(publications_per_year['Year'], publications_per_year['Quantity'], marker='o')
plt.title('Quantity of Publications Over Time - PL Data')
plt.xlabel('Year')
plt.ylabel('Quantity of Publications')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import altair as alt

# Load the data
pl_data_df = pd.read_csv('../chroniclingamerica_csv/pl_data.csv')

# Ensure the 'Date' column is in datetime format
pl_data_df['Date'] = pd.to_datetime(pl_data_df['date'])

# Group by year and count the number of publications
pl_data_df['Year'] = pl_data_df['Date'].dt.year
publications_per_year = pl_data_df.groupby('Year').size().reset_index(name='Quantity')

# Create the Altair chart
chart = alt.Chart(publications_per_year).mark_line(point=True).encode(
    x='Year:O',
    y='Quantity:Q',
    tooltip=['Year', 'Quantity']
).properties(
    title='Quantity of Publications Over Time - Altair PL Data',
    width=800,
    height=400
).interactive()

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
pl_data_df = pd.read_csv('../chroniclingamerica_csv/nnl_data.csv')

# Ensure the 'Date' column is in datetime format
pl_data_df['Date'] = pd.to_datetime(pl_data_df['date'])

# Group by year and count the number of publications
pl_data_df['Year'] = pl_data_df['Date'].dt.year
publications_per_year = pl_data_df.groupby('Year').size().reset_index(name='Quantity')

# Plot the time series
plt.figure(figsize=(10, 6))
plt.plot(publications_per_year['Year'], publications_per_year['Quantity'], marker='o')
plt.title('Quantity of Publications Over Time - NNL Data')
plt.xlabel('Year')
plt.ylabel('Quantity of Publications')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import altair as alt

# Load the data
pl_data_df = pd.read_csv('../chroniclingamerica_csv/nnl_data.csv')

# Ensure the 'Date' column is in datetime format
pl_data_df['Date'] = pd.to_datetime(pl_data_df['date'])

# Group by year and count the number of publications
pl_data_df['Year'] = pl_data_df['Date'].dt.year
publications_per_year = pl_data_df.groupby('Year').size().reset_index(name='Quantity')

# Create the Altair chart
chart = alt.Chart(publications_per_year).mark_line(point=True).encode(
    x='Year:O',
    y='Quantity:Q',
    tooltip=['Year', 'Quantity']
).properties(
    title='Quantity of Publications Over Time - Altair NNL Data',
    width=800,
    height=400
).interactive()

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
pl_data_df = pd.read_csv('../chroniclingamerica_csv/fl_data.csv')

# Ensure the 'Date' column is in datetime format
pl_data_df['Date'] = pd.to_datetime(pl_data_df['date'])

# Group by year and count the number of publications
pl_data_df['Year'] = pl_data_df['Date'].dt.year
publications_per_year = pl_data_df.groupby('Year').size().reset_index(name='Quantity')

# Plot the time series
plt.figure(figsize=(10, 6))
plt.plot(publications_per_year['Year'], publications_per_year['Quantity'], marker='o')
plt.title('Quantity of Publications Over Time - FL Data')
plt.xlabel('Year')
plt.ylabel('Quantity of Publications')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import altair as alt

# Load the data
pl_data_df = pd.read_csv('../chroniclingamerica_csv/fl_data.csv')

# Ensure the 'Date' column is in datetime format
pl_data_df['Date'] = pd.to_datetime(pl_data_df['date'])

# Group by year and count the number of publications
pl_data_df['Year'] = pl_data_df['Date'].dt.year
publications_per_year = pl_data_df.groupby('Year').size().reset_index(name='Quantity')

# Create the Altair chart
chart = alt.Chart(publications_per_year).mark_line(point=True).encode(
    x='Year:O',
    y='Quantity:Q',
    tooltip=['Year', 'Quantity']
).properties(
    title='Quantity of Publications Over Time - Altair FL Data',
    width=800,
    height=400
).interactive()

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
pl_data_df = pd.read_csv('../chroniclingamerica_csv/ecl_data.csv')

# Ensure the 'Date' column is in datetime format
pl_data_df['Date'] = pd.to_datetime(pl_data_df['date'])

# Group by year and count the number of publications
pl_data_df['Year'] = pl_data_df['Date'].dt.year
publications_per_year = pl_data_df.groupby('Year').size().reset_index(name='Quantity')

# Plot the time series
plt.figure(figsize=(10, 6))
plt.plot(publications_per_year['Year'], publications_per_year['Quantity'], marker='o')
plt.title('Quantity of Publications Over Time - ECL Data')
plt.xlabel('Year')
plt.ylabel('Quantity of Publications')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import altair as alt

# Load the data
pl_data_df = pd.read_csv('../chroniclingamerica_csv/ecl_data.csv')

# Ensure the 'Date' column is in datetime format
pl_data_df['Date'] = pd.to_datetime(pl_data_df['date'])

# Group by year and count the number of publications
pl_data_df['Year'] = pl_data_df['Date'].dt.year
publications_per_year = pl_data_df.groupby('Year').size().reset_index(name='Quantity')

# Create the Altair chart
chart = alt.Chart(publications_per_year).mark_line(point=True).encode(
    x='Year:O',
    y='Quantity:Q',
    tooltip=['Year', 'Quantity']
).properties(
    title='Quantity of Publications Over Time - Altair ECL Data',
    width=800,
    height=400
).interactive()

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
pl_data_df = pd.read_csv('../chroniclingamerica_csv/aa_data.csv')

# Ensure the 'Date' column is in datetime format
pl_data_df['Date'] = pd.to_datetime(pl_data_df['date'])

# Group by year and count the number of publications
pl_data_df['Year'] = pl_data_df['Date'].dt.year
publications_per_year = pl_data_df.groupby('Year').size().reset_index(name='Quantity')

# Plot the time series
plt.figure(figsize=(10, 6))
plt.plot(publications_per_year['Year'], publications_per_year['Quantity'], marker='o')
plt.title('Quantity of Publications Over Time - AA Data')
plt.xlabel('Year')
plt.ylabel('Quantity of Publications')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import altair as alt

# Load the data
pl_data_df = pd.read_csv('../chroniclingamerica_csv/aa_data.csv')

# Ensure the 'Date' column is in datetime format
pl_data_df['Date'] = pd.to_datetime(pl_data_df['date'])

# Group by year and count the number of publications
pl_data_df['Year'] = pl_data_df['Date'].dt.year
publications_per_year = pl_data_df.groupby('Year').size().reset_index(name='Quantity')

# Create the Altair chart
chart = alt.Chart(publications_per_year).mark_line(point=True).encode(
    x='Year:O',
    y='Quantity:Q',
    tooltip=['Year', 'Quantity']
).properties(
    title='Quantity of Publications Over Time - Altair AA Data',
    width=800,
    height=400
).interactive()

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Yosef - This code loads and concatenates data from multiple CSV files, filters and processes the data, and prepares it for analysis by grouping it by year, newspaper, league, and source.

# %%
# Enable the use of larger datasets in Altair
alt.data_transformers.disable_max_rows()

# Define the file paths and their corresponding labels
file_paths = {
    '../chroniclingamerica_csv/pl_data.csv': 'PL',
    '../chroniclingamerica_csv/nnl_data.csv': 'NNL',
    '../chroniclingamerica_csv/fl_data.csv': 'FL',
    '../chroniclingamerica_csv/ecl_data.csv': 'ECL',
    '../chroniclingamerica_csv/aa_data.csv': 'AA'
}

# Initialize an empty DataFrame to store all data
all_data = pd.DataFrame()

# Load and concatenate data from all CSV files
for file_path, label in file_paths.items():
    df = pd.read_csv(file_path, skiprows=1, names=['Newspaper', 'League', 'Date', 'URL'])
    # if label == 'AA':
    #     df = df[(df['Date'] >= '1881-01-01') & (df['Date'] <= '1900-12-31')]  # Filter by active years in aa_data.csv since aa_data.csv has about 62k rows
    df['Source'] = label  # Add a column to identify the source file
    all_data = pd.concat([all_data, df], ignore_index=True)

all_data['Date'] = pd.to_datetime(all_data['Date'], errors='coerce')

all_data = all_data.dropna(subset=['Date'])

# Group by year, newspaper, league, and source, and count the number of publications
all_data['Year'] = all_data['Date'].dt.year
publications_per_year = all_data.groupby(['Year', 'Newspaper', 'League', 'Source']).size().reset_index(name='Quantity')

# %% [markdown]
# ### Yosef - charted data of ALL the leagues combined via Altair

# %%
import altair as alt

selection = alt.selection_multi(fields=['League'], bind='legend')

chart = alt.Chart(publications_per_year).mark_circle(size=60).encode(
    x='Year:O',
    y=alt.Y('Quantity:Q', scale=alt.Scale(domain=[0, 800])),  
    color=alt.Color('League:N', scale=alt.Scale(scheme='category10'), legend=alt.Legend(title="League", orient="top-right")),  
    tooltip=['Year', 'Quantity', 'Newspaper', 'League', 'Source'],
    opacity=alt.condition(selection, alt.value(1), alt.value(0.05)) 
).properties(
    title='Quantity of Publications Over Time - Altair Data',
    width=800,
    height=400
).add_selection(
    selection
).interactive()

chart
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.Chart(...)

# %% [markdown]
# ### Kohta - more visualizations on the data via lineplot.

# %%
import pandas as pd

df_ecl = pd.read_csv('../chroniclingamerica_csv/ecl_data.csv')
df_fl = pd.read_csv('../chroniclingamerica_csv/fl_data.csv')
df_nnl = pd.read_csv('../chroniclingamerica_csv/nnl_data.csv')
df_pl = pd.read_csv('../chroniclingamerica_csv/pl_data.csv')

df_ecl['year'] = pd.to_datetime(df_ecl['date']).dt.year
df_fl['year'] = pd.to_datetime(df_fl['date']).dt.year
df_nnl['year'] = pd.to_datetime(df_nnl['date']).dt.year
df_pl['year'] = pd.to_datetime(df_pl['date']).dt.year

df_ecl_agg = df_ecl[['newspaper', 'year']].groupby('year').agg('count').reset_index()
df_fl_agg = df_fl[['newspaper', 'year']].groupby('year').agg('count').reset_index()
df_nnl_agg = df_nnl[['newspaper', 'year']].groupby('year').agg('count').reset_index()
df_pl_agg = df_pl[['newspaper', 'year']].groupby('year').agg('count').reset_index()

# %%
import altair as alt

# Combine all aggregated dataframes into one
df_combined = pd.concat([
    df_ecl_agg.assign(league='Eastern Colored League'),
    df_fl_agg.assign(league='Federal League'),
    df_nnl_agg.assign(league='Negro National League'),
    df_pl_agg.assign(league='Players League')
])

# Create a selection that will allow for interaction
selection = alt.selection_point(fields=['league'], bind='legend')
zoom = alt.selection_interval(bind='scales')
chart = alt.Chart(df_combined).mark_line().encode(
    x='year:O',
    y='newspaper:Q',
    color=alt.Color('league:N', legend=alt.Legend(title="League")),
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2)),
    tooltip=['year', 'newspaper', 'league']
).add_selection(
    zoom  # Add the zoom and pan capability
).add_params(
    selection
).properties(
    title='Number of Newspapers Over Years by League'
)


chart
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.Chart(...)

# %%
import altair as alt
import pandas as pd

# Combine all aggregated dataframes into one
df_combined = pd.concat([
    df_ecl_agg.assign(league='Eastern Colored League'),
    df_fl_agg.assign(league='Federal League'),
    df_nnl_agg.assign(league='Negro National League'),
    df_pl_agg.assign(league='Players League')
])

# Create a dropdown selection
dropdown = alt.binding_select(options=[
    'Eastern Colored League', 
    'Federal League', 
    'Negro National League', 
    'Players League'
], name='League: ')
selection = alt.param(name='LeagueSelector', bind=dropdown, value='Eastern Colored League')

# Add zoom and pan capability
zoom = alt.selection_interval(bind='scales')

# Create the chart
chart = alt.Chart(df_combined).mark_line().encode(
    x='year:O',
    y='newspaper:Q',
    color=alt.Color('league:N', legend=alt.Legend(title="League")),
    tooltip=['year', 'newspaper', 'league']
).add_params(
    zoom,  # Add zoom and pan capability
    selection  # Add dropdown parameter
).transform_filter(
    alt.datum.league == selection  # Filter rows based on dropdown selection
).properties(
    title='Number of Newspapers Over Years by League',
    width=800,
    height=400
)

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# Ethan - Next, we examined the specific newspapers that published the most papers for each league.

# %%
grouped_data = all_data.groupby(['League', 'Newspaper']).size().reset_index(name='Quantity')

top_newspapers = grouped_data.groupby('League').apply(lambda x: x.nlargest(10, 'Quantity')).reset_index(drop=True)

bubble_chart = alt.Chart(top_newspapers).mark_circle().encode(
    x=alt.X('Newspaper:N', sort='-y', title='Newspaper'),
    y=alt.Y('Quantity:Q', title='Number of Publications'),
    size=alt.Size('Quantity:Q', title='Number of Publications'),
    color='League:N',
    tooltip=['League', 'Newspaper', 'Quantity']
).properties(
    title='Top 10 Newspapers by Number of Publications for Each League',
    width=800,
    height=400
).configure_axis(
    labelAngle=-45
).configure_title(
    fontSize=16
)

bubble_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# Yosef - Made it interactive so you can select by league

# %%
import altair as alt

# Create a selection that will allow for interaction
selection = alt.selection_multi(fields=['League'], bind='legend')
click = alt.selection_multi(fields=['Quantity'], bind='legend')

chart = alt.Chart(top_newspapers).mark_circle().encode(
    x=alt.X('Newspaper:N', sort='-y', title='Newspaper'),
    y=alt.Y('Quantity:Q', title='Number of Publications'),
    size=alt.Size('Quantity:Q', title='Number of Publications'),
    color=alt.Color('League:N', legend=alt.Legend(title="League", orient="top")),
    tooltip=['League', 'Newspaper', 'Quantity'],
    opacity=alt.condition(selection & click, alt.value(1), alt.value(0.2))
).properties(
    title='Top 10 Newspapers by Number of Publications for Each League',
    width=800,
    height=400
).add_selection(
    selection
).add_selection(
    click
).configure_axis(
    labelAngle=-45
).configure_title(
    fontSize=16
).interactive()

chart
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'selection_multi' is deprecated.  Use 'selection_point'
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# /opt/anaconda3/lib/python3.12/site-packages/altair/utils/deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.Chart(...)

# %% [markdown]
# Ethan - Lastly, we calculated the average publications per year during the time that each league was active

# %%
years_active = {
    "american association": [1882, 1891],
    "eastern colored league": [1923, 1928],
    "federal league": [1913, 1915],
    "negro national league": [1920, 1948], #Its important to note that there were actually two negro national leagues, one from 1920-1931 and one from 1933-1948 (the gap is typically attributed to the great depression)
    "players league": [1890, 1891]
}

# %%
all_data_active = pd.DataFrame()
for league, years in years_active.items():
    all_data_active = pd.concat([all_data_active, all_data[(all_data["League"] == league) & (all_data["Year"] >= years[0]) & (all_data["Year"] <= years[1])]])

# %%
all_data_active_grouped = all_data_active.groupby("League").size()

average_publications = {}
for league, years in years_active.items():
    start_year, end_year = years
    total_years = end_year - start_year + 1
    league_publications = all_data_active_grouped.get(league, 0)
    average_publications[league] = league_publications / total_years


avgs_df = pd.DataFrame.from_dict(average_publications, orient="index", columns=["Avg_Publications_Per_Year"])


print(avgs_df)
# Out:
#                         Avg_Publications_Per_Year
# american association                   100.900000
# eastern colored league                  17.166667
# federal league                        9569.666667
# negro national league                   27.965517
# players league                         827.000000

# %% [markdown]
# ### Ethan -Next, we have some code that generates word clouds. The top code generates a word cloud for a random article. The next code block collects a sample of 10 (increase this number for a greater representation) articles from each league.
#
# #### We use the computational method Named Entity Recognition using REGEX (There were issues with dependencies and python version when trying to use NLP libraries.)

# %%
import random
from collections import defaultdict
import requests
from io import BytesIO
from PyPDF2 import PdfReader
from wordcloud import WordCloud
import re
import matplotlib.pyplot as plt




def create_wordcloud_from_text(text, title):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title(title)
    plt.show()

def extract_names_from_text(text):
    # A basic regex pattern for names (first and last, capitalized)
    name_pattern = r'\b[A-Z][a-z]+\s[A-Z][a-z]+\b'
    return re.findall(name_pattern, text)

def create_wordcloud_from_pdf(url):
    response = requests.get(url)
    if response.status_code != 200:
        raise Exception(f"Failed to fetch PDF from {url}")
    pdf_data = BytesIO(response.content)

    reader = PdfReader(pdf_data)
    text = ""
    for page in reader.pages:
        page_text = page.extract_text()
        if page_text:
            names = extract_names_from_text(page_text)
            text += " ".join(names) + " "
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

sample_row = all_data.sample(n=1).iloc[0]
pdf_url = sample_row['URL']
title = f"{sample_row['League']} - {sample_row['Newspaper']} ({sample_row['Date'].strftime('%Y-%m-%d')})"
create_wordcloud_from_pdf(pdf_url)
print(title)
# Out:
# american association - The Keota news. (1913-08-01)

# %%
# Group the data by league and collect a random sample of 10 articles for each league
grouped_data = all_data.groupby('League')
sampled_data = defaultdict(list)

for league, group in grouped_data:
    sampled_data[league] = group.sample(n=min(10, len(group)), random_state=42)

# Generate word clouds for each league
for league, sample in sampled_data.items():
    text = ""
    for url in sample['URL']:
        response = requests.get(url)
        if response.status_code == 200:
            pdf_data = BytesIO(response.content)
            reader = PdfReader(pdf_data)
            for page in reader.pages:
                page_text = page.extract_text()
                if page_text:
                    # Use regex to extract names from the page text
                    names = extract_names_from_text(page_text)
                    text += " ".join(names) + " "
    
    create_wordcloud_from_text(text, f"Word Cloud for {league}")
