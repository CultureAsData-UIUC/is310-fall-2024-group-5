# %%
import pandas as pd
df = pd.read_csv('player-stats-2024.csv')

# %%
likes = ['Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']

df['Like'] = likes

jason_likes=['No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes!', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes']

df['Jason Likes']=jason_likes

# Save the updated dataset
df.to_csv('player-stats-2024.csv', index=False)

df
# Out:
#     Rk                 Player  Year  xwOBA  BA - xBA  Avg EV (MPH)  \
# 0    1            Judge Aaron  2024  0.484     0.007          96.2
# 1    2          Ohtani Shohei  2024  0.448    -0.010          95.8
# 2    3             Cruz Oneil  2024  0.342    -0.007          95.5
# 3    4              Soto Juan  2024  0.463    -0.031          94.2
# 4    5            Marte Ketel  2024  0.395    -0.006          94.0
# 5    6  Guerrero Jr. Vladimir  2024  0.410     0.000          93.8
# 6    7         Schwarber Kyle  2024  0.380    -0.009          93.6
# 7    8          Devers Rafael  2024  0.366    -0.002          93.2
# 8    9           Chapman Matt  2024  0.344    -0.007          93.2
# 9   10         Alvarez Yordan  2024  0.414     0.003          93.1
# 10  11      Contreras William  2024  0.360     0.010          92.8
# 11  12       Henderson Gunnar  2024  0.379    -0.008          92.8
# 12  13         Witt Jr. Bobby  2024  0.413     0.011          92.7
# ...
